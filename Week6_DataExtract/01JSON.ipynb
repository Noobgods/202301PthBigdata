# %% [markdown]
# JSON : JavaScript Object Notation
# ```
# {
#   "Key1" : "Value1",
#   "Key2" : "Value2"
# }
# ```

# %%
d = {"name":"데이터 분석"}
print(d['name'])
print(type(d))
# Out:
# 데이터 분석
# <class 'dict'>

# %%
import json

d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
print(type(d_str))
# Out:
# {"name": "데이터 분석"}
# <class 'str'>

# %%
d2 = json.loads(d_str)
print(d2['name'])
print(type(d2))
# Out:
# 데이터 분석
# <class 'dict'>

# %%
d3_str = '''
{
  "name" : "데이터 분석", 
  "author" : ["홍길동", "김철수"], 
  "year" : 2023
}
'''
d3 = json.loads(d3_str)
print(d3['author'][1])
# Out:
# 김철수

# %%
import pandas as pd

json_df = pd.read_json(d3_str)  # json -> DataFrame
list_df = pd.DataFrame(d3)      # Python 리스트 -> DataFrame

print(json_df)
print(type(json_df))
print(list_df)
print(type(list_df))
# Out:
#      name author  year
# 0  데이터 분석    홍길동  2023
# 1  데이터 분석    김철수  2023
# <class 'pandas.core.frame.DataFrame'>
#      name author  year
# 0  데이터 분석    홍길동  2023
# 1  데이터 분석    김철수  2023
# <class 'pandas.core.frame.DataFrame'>
