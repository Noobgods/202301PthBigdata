# %%
import gdown
filename = 'PtLibraryData.csv'
url = 'https://drive.google.com/uc?id=14EDAU0RhBrloiwS_ieDo7xrKb4w5wkmj'
gdown.download(url, filename, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14EDAU0RhBrloiwS_ieDo7xrKb4w5wkmj
# To: /content/PtLibraryData.csv
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 118MB/s]
# 'PtLibraryData.csv'

# %%
import chardet

with open(filename, mode='rb') as f:
  d = f.readline()

print(chardet.detect(d))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import pandas as pd

df = pd.read_csv(filename, encoding='utf-8', low_memory=False)
df.head()
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9.79117E+12      NaN    0  NaN  199.1     1     0  2023-03-30
# 1  9.79113E+12      NaN    1  NaN  373.7     1     0  2023-03-30
# 2  9.79117E+12      NaN    1  NaN  376.6     1     0  2023-03-30
# 3  9.79117E+12      NaN    4  NaN  813.7     1     0  2023-03-30
# 4  9.78895E+12      NaN    0  NaN  813.7     1     0  2023-03-30

# %%
df.to_csv('output230504.csv')

# %%
output_df = pd.read_csv('output230504.csv', index_col=0, low_memory= False)
output_df.head()
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9.79117E+12      NaN    0  NaN  199.1     1     0  2023-03-30
# 1  9.79113E+12      NaN    1  NaN  373.7     1     0  2023-03-30
# 2  9.79117E+12      NaN    1  NaN  376.6     1     0  2023-03-30
# 3  9.79117E+12      NaN    4  NaN  813.7     1     0  2023-03-30
# 4  9.78895E+12      NaN    0  NaN  813.7     1     0  2023-03-30

# %%
output_df.to_csv('output230504_2.csv', index=False)
